# %% [markdown]
# # this is a header

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# %matplotlib inline

# %%
a = 1
b = 100
b
# Out:
# 100

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.tan(x)

plt.plot(x, y1)
plt.plot(x, y2)
plt.show()
