# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# %matplotlib inline

# %%
df = pd.read_csv("input/report_07-23.csv")
df.sample(10)
# Out:
#        index           time_stamp  stop                  stopName  number  \
# 23304    849  2018-07-23 11:20:54    79            Plac Inwalidów      24
# 9781     350  2018-07-23 08:10:41  2543                Wańkowicza       1
# 62133   2277  2018-07-23 20:27:01  2870  Dworzec Płaszów Estakada      11
# 29011   1086  2018-07-23 12:48:30  2870  Dworzec Płaszów Estakada      11
# 20076    719  2018-07-23 10:31:17  2688               Norymberska      18
# 35785   1364  2018-07-23 14:31:49  3033                     Plaza       1
# 64245   2376  2018-07-23 21:04:37    73              Politechnika      50
# 40091   1515  2018-07-23 15:29:05  3033                     Plaza      22
# 39114   1483  2018-07-23 15:16:44    84                 Biprostal      13
# 50954   1870  2018-07-23 17:48:30   413               Os.Kolorowe      10
#
#                direction          plannedTime     vehicleId  \
# 23304     Bronowice Małe  2018-07-23 11:22:00  6.352185e+18
# 9781            Salwator  2018-07-23 08:09:00  6.352185e+18
# 62133       Mały Płaszów  2018-07-23 20:23:00  6.352185e+18
# 29011  Czerwone Maki P+R  2018-07-23 12:48:00  6.352185e+18
# 20076  Czerwone Maki P+R  2018-07-23 10:31:00  6.352185e+18
# 35785           Salwator  2018-07-23 14:28:00  6.352185e+18
# 64245    Krowodrza Górka  2018-07-23 21:03:00  6.352185e+18
# 40091          Walcownia  2018-07-23 15:25:00  6.352185e+18
# 39114          Bronowice  2018-07-23 15:15:00           NaN
# 50954       Kopiec Wandy  2018-07-23 17:43:00  6.352185e+18
#
#                     tripId     status  delay  seq_num
# 23304  6351558574044936456  PREDICTED      0     20.0
# 9781   6351558574044391684   STOPPING      1      5.0
# 62133  6351558574044670228  PREDICTED      4     19.0
# 29011  6351558574044674315  PREDICTED      0      4.0
# 20076  6351558574044793095   STOPPING      0     22.0
# 35785  6351558574044371208  PREDICTED      3     17.0
# 64245  6351558574045026584   STOPPING      1     14.0
# 40091  6351558574044911881   STOPPING      4     23.0
# 39114  6351558574044723465    PLANNED      1     25.0
# 50954  6351558574044657935   STOPPING      5     21.0

# %%
#check specific trip
df[df.tripId == 6351558574044936456]
# Out:
#        index           time_stamp  stop                  stopName  number  \
# 21231    764  2018-07-23 10:49:09   718                    Witosa      24
# 21277    766  2018-07-23 10:49:48  3176             Kurdwanów P+R      24
# 21344    768  2018-07-23 10:50:50   715               Nowosądecka      24
# 21456    772  2018-07-23 10:52:27   716               Piaski Nowe      24
# 21564    777  2018-07-23 10:54:16   632                     Dauna      24
# 21703    783  2018-07-23 10:56:23   630               Bieżanowska      24
# 21806    787  2018-07-23 10:57:54   624                     Kabel      24
# 21922    792  2018-07-23 10:59:50   623                  Dworcowa      24
# 22037    797  2018-07-23 11:01:40   621        Cmentarz Podgórski      24
# 22141    801  2018-07-23 11:03:11  3158              Podgórze SKA      24
# 22282    806  2018-07-23 11:05:09   570      Plac Bohaterów Getta      24
# 22316    808  2018-07-23 11:05:46  2742              Św.Wawrzyńca      24
# 22473    814  2018-07-23 11:07:58   362                   Miodowa      24
# 22676    822  2018-07-23 11:11:00   358               Starowiślna      24
# 22744    825  2018-07-23 11:12:03   357             Poczta Główna      24
# 22909    832  2018-07-23 11:14:37   131            Dworzec Główny      24
# 23042    838  2018-07-23 11:16:47  3032             Stary Kleparz      24
# 22037   STOPPING      1      9.0
# 22141   STOPPING      1     10.0
# 22282   STOPPING      0     11.0
# 22316  PREDICTED      0     12.0
# 22473   STOPPING      0     13.0
# 22676   STOPPING      0     14.0
# 22744   STOPPING      0     15.0
# 22909   STOPPING      0     16.0
# 23042   STOPPING      0     17.0
# 23230   STOPPING      0     18.0
# 23303  PREDICTED      0     19.0
# 23304  PREDICTED      0     20.0
# 23564   STOPPING      0     21.0
# 23654   STOPPING      0     22.0
# 23756   STOPPING      0     23.0
# 23851   STOPPING      1     24.0
# 23950   STOPPING      0     25.0
# 24025   STOPPING      0     26.0
# 24182   STOPPING      1     27.0

# %%
#check how often delays happen
df.delay.value_counts(normalize=True)
# Out:
# 0     0.426905
# 1     0.344715
# 2     0.123509
# 3     0.055987
# 4     0.025421
# 5     0.011410
# 6     0.004852
# 7     0.002657
# 8     0.001189
# 9     0.000867
# 10    0.000587
# 14    0.000503
# 12    0.000475
# 11    0.000350
# 13    0.000336
# 15    0.000154
# 16    0.000042
# 19    0.000028
# 18    0.000014
# Name: delay, dtype: float64

# %%
df.delay.hist(bins=15);

# %%
df.delay.describe()
# Out:
# count    71517.000000
# mean         1.014039
# std          1.357324
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max         19.000000
# Name: delay, dtype: float64

# %%
#use seconds instead of minutes in delay to get better accuracy
df['delay_secs'] = df['delay'] * 60
df.delay_secs.sample(5)
# Out:
# 25597    240
# 64123    240
# 47575     60
# 18567    120
# 3530       0
# Name: delay_secs, dtype: int64

# %%
#change string 'direction' to numerical value
df['direction_cat'] = df.direction.factorize()[0]
df.direction_cat.sample(5)
# Out:
# 8918     12
# 32013    16
# 69467    11
# 17992    14
# 46589     0
# Name: direction_cat, dtype: int64

# %%
#fill in missing valus in vehicleId
df.vehicleId.fillna(-1, inplace=True) #inplace - no need to "=" to a new value 
df.vehicleId.sample(5)
# Out:
# 28736    6.352185e+18
# 52054    6.352185e+18
# 47217    6.352185e+18
# 16307    6.352185e+18
# 9186    -1.000000e+00
# Name: vehicleId, dtype: float64

# %%
#fill in missing valus in seq_num
df.seq_num.fillna(-1, inplace=True)
df.seq_num.sample(5)
# Out:
# 60583    20.0
# 50229    12.0
# 60843    11.0
# 64975     4.0
# 61753     2.0
# Name: seq_num, dtype: float64

# %%
#feature engineering
def gen_id_num_direction(x):
    return '{} {}'.format(x['number'], x['direction'])
    
df['number_direction_id'] = df.apply(gen_id_num_direction, axis=1).factorize()[0]

def gen_id_stop_direction(x):
    return '{} {}'.format(x['stop'], x['direction'])

df['stop_direction_id'] = df.apply(gen_id_stop_direction, axis=1).factorize()[0]

# %%
feats = [
         'number', 
         'stop', 
         'direction_cat', 
         'vehicleId', 
         'seq_num',
        # 'number_direction_id', 
         #'stop_direction_id'
        ]
X = df[feats].values
y = df['delay_secs'].values

model = DecisionTreeRegressor(max_depth=10)
scores = cross_val_score(model, X, y, cv=3, scoring='neg_mean_absolute_error')

np.mean(scores), np.std(scores)
# Out:
# (-48.910876848316754, 2.5260014875124384)

# %%
#Random Forest
model2 = RandomForestRegressor(max_depth=10, n_estimators=50, n_jobs=8)
scores2 = cross_val_score(model, X, y, cv=3, scoring='neg_mean_absolute_error')

np.mean(scores2), np.std(scores2)
# Out:
# (-48.876146725539805, 2.5307551626968756)

# %% [markdown]
# number_direction_id and stop_direction_id actually made out model worse
# so we commented them out
